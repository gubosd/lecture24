# %% [markdown]
# ## 이미지 처리 딥러닝
# # YOLO (You Only Look Once)
# - Object Detection

# %% [markdown]
# ### YOLO-v1
# - https://curt-park.github.io/2017-03-26/yolo/
# - 출력의 깊이는 Bx2 + C => (박스수\*2 + 클래스수)

# %% [markdown]
# <img src="https://curt-park.github.io/images/yolo/DeepSystems-NetworkArchitecture.JPG" /> <br>
# <img src="https://curt-park.github.io/images/yolo/NetArch0.JPG" />

# %% [markdown]
# <img src="https://curt-park.github.io/images/yolo/Figure6.JPG" />

# %% [markdown]
# ### YOLO-v2
# - 최종 출력의 깊이는 Bx(5+C) => 박스수*(5+클래스수)

# %% [markdown]
# <img src="https://www.researchgate.net/publication/336177198/figure/fig4/AS:809235726229506@1569948240717/The-architecture-of-YOLOv2.ppm" />

# %% [markdown]
# ### YOLO-v3
# - https://towardsdatascience.com/yolo-v3-object-detection-53fb7d3bfe6b
# - 출력층이 3개 (13x13x255, 26x26x255, 52x52x255)
# > 255 = B\*(5+C), B=3, C=80

# %% [markdown]
# <img src="https://miro.medium.com/max/3802/1*d4Eg17IVJ0L41e7CTWLLSg.png" />

# %% [markdown]
# ### Keras 용 YOLO 설치
# - https://github.com/qqwweee/keras-yolo3

# %% [markdown]
# #### 설치 절차
# - Microsoft Visual C++ redistributable(vc_redist.x64.exe) 설치
# - 가상환경 생성 : conda create -n keras-yolo3 python=3.5
# - 가상환경 실행 : activate keras-yolo3
# - pip install tensorflow==1.6.0
# - pip install keras==2.1.5
# - pip install h5py, Pillow, matplotlib, opencv-python
# <hr/>
#
# #### 실행 절차
# - https://github.com/qqwweee/keras-yolo3 깃허브 다운로드
# - https://pjreddie.com/media/files/yolov3.weights 다운로드
# - python convert.py yolov3.cfg yolov3.weights model_data/yolo.h5
# - 이미지 검출 : python yolo_video.py --image
# - 비디오 검출 : python yolo_video.py --input test.mp4 --output test_result.mp4

# %% [markdown]
# #### 실행결과 예시
# ```
# cell phone 0.39 (185, 119) (193, 131)
# truck 0.53 (64, 170) (118, 253)
# truck 0.59 (2, 161) (89, 270)
# bus 0.55 (2, 166) (88, 274)
# car 0.32 (2, 166) (88, 274)
# car 0.64 (232, 198) (277, 254)
# car 0.93 (236, 160) (354, 262)
# person 1.00 (106, 22) (194, 335)
# person 1.00 (172, 33) (239, 338)
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
